# %% [markdown]
# #
#
# <figure>
# <img src="attachment:../../images/uq1.jpg"
# alt="An interactive LADAL notebook" />
# <figcaption aria-hidden="true">An interactive LADAL
# notebook</figcaption>
# </figure>
#
# # Pos-Tagging Tool
#
# This notebook-based tool accompanies the [*Language Technology and Data
# Analysis Laboratory* (LADAL) tutorial **Part-of-Speech Tagging and
# Dependency Parsing with R**](tutorials/postag/postag.html).
#
# ## Using your own data
#
# <span>
#
# <p style="margin-top:1em; text-align:center">
#
# To <b>use your own data</b>, click on the folder called <b>`MyTexts`</b>
# (it is in the menu to the left of the screen) and then simply drag and
# drop your txt-files into the folder. <br>When you then execute the code
# chunk below, you will upload your own data and you can then use it in
# this notebook.<br>You can upload <b>only txt-files</b> (simple
# unformatted files created in or saved by a text editor)! <br>The
# notebook assumes that you upload some form of text data - not tabular
# data! <br>
#
# </p>
#
# <p style="margin-left:1em;">
#
# </p>
#
# </span>
#
# <br>

# %%
# load function that helps loading texts
source("tools/postool/rscripts/loadtxts.R")
# Out:
# Attaching package: 'dplyr'
# The following objects are masked from 'package:stats':
#
#     filter, lag
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# here() starts at /Users/laurenceanthony/Documents/projects/LADALQ
# Package version: 4.1.0
# Unicode version: 14.0
# ICU version: 71.1
# Parallel computing: disabled
# See https://quanteda.io for tutorials and examples.
# Loading required package: proxyC
# Attaching package: 'proxyC'
# The following object is masked from 'package:stats':
#
#     dist
# Attaching package: 'seededlda'
# The following object is masked from 'package:quanteda':
#
#     info_tbb
# The following object is masked from 'package:stats':
#
#     terms
#  Named chr [1:7] "Linguistics is the scientific study of language. It involves analysing language form language meaning and langu"| __truncated__ ...
# ...

# %% [markdown]
# ## Pos tagging
#
# Now we can pos-tag the text using the `postag` function. This function
# has the following arguments:
#
# -   `x`: a text or collection of texts.
# -   `language`: the language model used for pos-tagging (these are the
#     availabel pre-trained models models: “afrikaans-afribooms”,
#     “ancient_greek-perseus”, “ancient_greek-proiel”, “arabic-padt”,
#     “armenian-armtdp”, “basque-bdt”, “belarusian-hse”, “bulgarian-btb”,
#     “buryat-bdt”, “catalan-ancora”, “chinese-gsd”, “chinese-gsdsimp”,
#     “classical_chinese-kyoto”, “coptic-scriptorium”, “croatian-set”,
#     “czech-cac”, “czech-cltt”, “czech-fictree”, “czech-pdt”,
#     “danish-ddt”, “dutch-alpino”, “dutch-lassysmall”, “english-ewt”,
#     “english-gum”, “english-lines”, “english-partut”, “estonian-edt”,
#     “estonian-ewt”, “finnish-ftb”, “finnish-tdt”, “french-gsd”,
#     “french-partut”, “french-sequoia”, “french-spoken”, “galician-ctg”,
#     “galician-treegal”, “german-gsd”, “german-hdt”, “gothic-proiel”,
#     “greek-gdt”, “hebrew-htb”, “hindi-hdtb”, “hungarian-szeged”,
#     “indonesian-gsd”, “irish-idt”, “italian-isdt”, “italian-partut”,
#     “italian-postwita”, “italian-twittiro”, “italian-vit”,
#     “japanese-gsd”, “kazakh-ktb”, “korean-gsd”, “korean-kaist”,
#     “kurmanji-mg”, “latin-ittb”, “latin-perseus”, “latin-proiel”,
#     “latvian-lvtb”, “lithuanian-alksnis”, “lithuanian-hse”,
#     “maltese-mudt”, “marathi-ufal”, “north_sami-giella”,
#     “norwegian-bokmaal”, “norwegian-nynorsk”, “norwegian-nynorsklia”,
#     “old_church_slavonic-proiel”, “old_french-srcmf”,
#     “old_russian-torot”, “persian-seraji”, “polish-lfg”, “polish-pdb”,
#     “polish-sz”, “portuguese-bosque”, “portuguese-br”, “portuguese-gsd”,
#     “romanian-nonstandard”, “romanian-rrt”, “russian-gsd”,
#     “russian-syntagrus”, “russian-taiga”, “sanskrit-ufal”,
#     “scottish_gaelic-arcosg”, “serbian-set”, “slovak-snk”,
#     “slovenian-ssj”,
#     “slovenian-sst”, “spanish-ancora”, “spanish-gsd”, “swedish-lines”,
#     “swedish-talbanken”, “tamil-ttb”, “telugu-mtg”, “turkish-imst”,
#     “ukrainian-iu”, “upper_sorbian-ufal”, “urdu-udtb”, “uyghur-udt”,
#     “vietnamese-vtb”, “wolof-wtb”))
#
# <span>
#
# <p style="margin-top:1em; text-align:center">
#
# The code chunk below assumes that you want to pos-tag English text(s).
# <br> If you want to pos-tag text in another language, replace
# “english-ext” with another pre-trained language model,<br>
# e.g. “german-gsd” for pos-tagging a German text (see above for available
# models). <br>
#
# </p>
#
# <p style="margin-left:1em;">
#
# </p>
#
# </span>
#
# <br>

# %%
# load function that pos-tags text
source("tools/postool/rscripts/postag.R")

# perform pos-tagging
postagged <- postag(text, language = "english-ewt")

# inspect result
str(postagged)
# Out:
#  Named chr [1:7] "Linguistics/NNS is/VBZ the/DT scientific/JJ study/NN of/IN language/NN ./. It/PRP involves/VBZ analysing/VBG la"| __truncated__ ...
#  - attr(*, "names")= chr [1:7] "linguistics01.txt" "linguistics02.txt" "linguistics03.txt" "linguistics04.txt" ...

# %% [markdown]
# ## Saving to MyOutput
#
# As a concluding step, we save the outcomes – the three files housing our
# cleaned texts – in the ‘MyOutput’ folder, conveniently visible on the
# left side of the screen.

# %%
# load function that helps loading texts
source("tools/postool/rscripts/savetxts.R")
savetxts(postagged)
# Out:
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL

# %% [markdown]
# <span>
#
# <p style="margin-top:1em; text-align:center">
#
# <b>You will find the txt-files in the `MyOutput` folder (located on the
# left side of the screen).</b> <br><br>Simply double-click the `MyOutput`
# folder icon, then highlight the files, and choose *Download* from the
# dropdown menu to download the files. <br>
#
# </p>
#
# <p style="margin-left:1em;">
#
# </p>
#
# </span>
#
# <br>
#
# ------------------------------------------------------------------------
#
# # Citation & Session Info
#
# Schweinberger, Martin. (2024)\` *LADAL Pos-Tagging Tool*. Brisbane: The
# University of Queensland. url: tools.html (Version 2024.04.21).
#
#     @manual{schweinberger2024postool,
#       author = {Schweinberger, Martin},
#       title = {LADAL Pos-Tagging Tool},
#       note = {tools.html},
#       year = {2024},
#       organization = {The University of Queensland, School of Languages and Cultures},
#       address = {Brisbane},
#       edition = {2024.04.21}
#     }
#
# [Back to LADAL](tutorials/net/net.html)
#
# ------------------------------------------------------------------------

# %%
sessionInfo()
# Out:
# R version 4.4.1 (2024-06-14)
# Platform: aarch64-apple-darwin20
# Running under: macOS Sonoma 14.6.1
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/lib/libRblas.0.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.4-arm64/Resources/lib/libRlapack.dylib;  LAPACK version 3.12.0
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# time zone: Australia/Brisbane
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] udpipe_0.8.11             writexl_1.5.1
#  [3] tidyr_1.3.1               stringr_1.5.1
#  [5] seededlda_1.4.1           proxyC_0.4.1
#  [7] quanteda.textstats_0.97.2 quanteda.textplots_0.95
#  [9] quanteda_4.1.0            here_1.0.1
# [11] ggplot2_3.5.1             dplyr_1.1.4
#
# loaded via a namespace (and not attached):
# ...
